# %%
import pandas as ps

# %%
data = ps.read_csv("sec_bhavdata_full.csv")

# %%
data.head()
# Out:
#        SYMBOL SERIES        DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 0   20MICRONS     EQ  04-Apr-2018       49.90       50.10       52.30
# 1  21STCENMGM     BE  04-Apr-2018       35.00       35.50       35.50
# 2  3IINFOTECH     EQ  04-Apr-2018        5.15        5.15        5.30
# 3     3MINDIA     EQ  04-Apr-2018    20111.30    20111.30    21000.05
# 4      5PAISA     BE  04-Apr-2018      344.15      349.80      357.80
#
#    LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  TURNOVER_LACS  \
# 0       49.0        49.5         49.3      50.98        193457          98.62
# 1       35.0        35.0         35.0      35.02          1487           0.52
# 2        5.0         5.1          5.1       5.14       3773118         193.91
# 3    19851.0     20131.0      20105.0   20530.85          3744         768.67
# 4      341.0       347.0        347.0     347.29          5110          17.75
#
#    NO_OF_TRADES DELIV_QTY DELIV_PER
# 0          1874     87220     45.08
# ...

# %%
temp = data.loc[:,['SYMBOL', 'SERIES', 'DATE1', 'OPEN_PRICE', 'CLOSE_PRICE']]

# %%
temp[temp['SERIES'] == 'EQ']
# Out:
#           SYMBOL SERIES        DATE1  OPEN_PRICE  CLOSE_PRICE
# 0      20MICRONS     EQ  04-Apr-2018       50.10        49.30
# 2     3IINFOTECH     EQ  04-Apr-2018        5.15         5.10
# 3        3MINDIA     EQ  04-Apr-2018    20111.30     20105.00
# 5        63MOONS     EQ  04-Apr-2018      101.00       101.05
# 6        8KMILES     EQ  04-Apr-2018      704.95       689.75
# 7       A2ZINFRA     EQ  04-Apr-2018       28.85        27.90
# 8     AARTIDRUGS     EQ  04-Apr-2018      540.80       543.80
# 9       AARTIIND     EQ  04-Apr-2018     1165.00      1154.60
# 10     AARVEEDEN     EQ  04-Apr-2018       46.45        44.20
# 12          ABAN     EQ  04-Apr-2018      163.70       159.65
# 13           ABB     EQ  04-Apr-2018     1294.90      1271.35
# 14    ABBOTINDIA     EQ  04-Apr-2018     5674.00      5624.50
# 15     ABCAPITAL     EQ  04-Apr-2018      152.90       151.70
# 16         ABFRL     EQ  04-Apr-2018      147.90       151.00
# ...
